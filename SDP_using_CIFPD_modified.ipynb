# %% [markdown]
# # SDP Using CIFPD - Refactored Workflow
#
# This notebook keeps the project readable while delegating the actual implementation to reusable Python modules.

# %%
# %pip install -r requirements.txt

# %% [markdown]
# ## Train the model
#
# Update the CSV path before running this cell.

# %%
from train_model import train_pipeline

CSV_PATH = 'Eclipse.csv'
metadata = train_pipeline(
    csv_path=CSV_PATH,
    artifact_dir='models',
    reports_dir='reports',
    feature_method='mutual_info',
)
metadata

# %% [markdown]
# ## Review saved evaluation

# %%
import json
from pathlib import Path

json.loads(Path('models/metadata.json').read_text())

# %% [markdown]
# ## Launch the UI
#
# Run this in a terminal:
#
# ```bash
# streamlit run app.py
# ```
